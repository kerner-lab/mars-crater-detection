# %%
import numpy as np 
import os
import tensorflow as tf
import skimage.io as io
import skimage.transform as trans
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
from tensorflow.keras.losses import BinaryCrossentropy
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, load_model
# Out:
# 2023-04-06 12:34:20.103912: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
(os.listdir('data256/train/images'))
# Out:
# ['thm_dir_N-30_240_-30_0_-120_-9016.png',
#  'thm_dir_N-30_180_-30_0_-180_-1500.png',
#  'thm_dir_N-30_030_-30_0_30_606.png',
#  'thm_dir_N-30_120_-30_0_120_15013.png',
#  'thm_dir_N-30_180_-30_0_-180_-15013.png',
#  'thm_dir_N00_060_0_30_60_9023.png',
#  'thm_dir_N-30_240_-30_0_-120_-909.png',
#  'thm_dir_N-30_300_-30_0_-60_-3014.png',
#  'thm_dir_N-30_300_-30_0_-60_-3028.png',
#  'thm_dir_N00_300_0_30_-60_-3016.png',
#  'thm_dir_N00_300_0_30_-60_-3017.png',
#  'thm_dir_N-30_300_-30_0_-60_-3029.png',
#  'thm_dir_N-30_300_-30_0_-60_-3015.png',
#  'thm_dir_N-30_240_-30_0_-120_-908.png',
#  'thm_dir_N00_060_0_30_60_9022.png',
#  'thm_dir_N-30_180_-30_0_-180_-15012.png',
#  'thm_dir_N-30_120_-30_0_120_15012.png',
#  'thm_dir_N-30_030_-30_0_30_607.png',
#  'thm_dir_N-30_180_-30_0_-180_-1501.png',
#  'thm_dir_N-30_240_-30_0_-120_-9017.png',
#  'thm_dir_N-30_240_-30_0_-120_-9015.png',
#  'thm_dir_N-30_180_-30_0_-180_-1503.png',
#  'thm_dir_N-30_240_-30_0_-120_-9029.png',
#  'thm_dir_N-30_030_-30_0_30_605.png',
#  'thm_dir_N-30_120_-30_0_120_15010.png',
#  'thm_dir_N-30_180_-30_0_-180_-15010.png',
#  'thm_dir_N00_060_0_30_60_9020.png',
#  'thm_dir_N-30_300_-30_0_-60_-3017.png',
#  'thm_dir_N00_300_0_30_-60_-3029.png',
#  'thm_dir_N00_300_0_30_-60_-3015.png',
#  'thm_dir_N00_300_0_30_-60_-3014.png',
#  'thm_dir_N00_300_0_30_-60_-3028.png',
#  'thm_dir_N-30_300_-30_0_-60_-3016.png',
#  'thm_dir_N00_060_0_30_60_9021.png',
#  'thm_dir_N-30_180_-30_0_-180_-15011.png',
#  'thm_dir_N-30_120_-30_0_120_15011.png',
#  'thm_dir_N-30_030_-30_0_30_604.png',
#  'thm_dir_N-30_240_-30_0_-120_-9028.png',
#  'thm_dir_N-30_180_-30_0_-180_-1502.png',
#  'thm_dir_N-30_240_-30_0_-120_-9014.png',
#  'thm_dir_N-30_180_-30_0_-180_-1506.png',
#  'thm_dir_N-30_240_-30_0_-120_-9010.png',
#  'thm_dir_N-30_120_-30_0_120_1508.png',
#  'thm_dir_N-30_120_-30_0_120_15015.png',
#  'thm_dir_N-30_030_-30_0_30_600.png',
#  'thm_dir_N-30_120_-30_0_120_15029.png',
#  'thm_dir_N00_060_0_30_60_9019.png',
#  'thm_dir_N-30_180_-30_0_-180_-15029.png',
#  'thm_dir_N-30_180_-30_0_-180_-15015.png',
#  'thm_dir_N00_060_0_30_60_9025.png',
#  'thm_dir_N-30_300_-30_0_-60_-3012.png',
#  '.DS_Store',
#  'thm_dir_N00_300_0_30_-60_-3010.png',
#  'thm_dir_N00_300_0_30_-60_-3011.png',
#  'thm_dir_N-30_300_-30_0_-60_-3013.png',
#  'thm_dir_N00_060_0_30_60_9024.png',
#  'thm_dir_N-30_180_-30_0_-180_-15014.png',
#  'thm_dir_N-30_180_-30_0_-180_-15028.png',
#  'thm_dir_N00_060_0_30_60_9018.png',
#  'thm_dir_N-30_120_-30_0_120_15028.png',
#  'thm_dir_N-30_030_-30_0_30_601.png',
#  'thm_dir_N-30_120_-30_0_120_15014.png',
#  'thm_dir_N-30_120_-30_0_120_1509.png',
#  'thm_dir_N-30_240_-30_0_-120_-9011.png',
#  'thm_dir_N-30_180_-30_0_-180_-1507.png',
#  'thm_dir_N-30_180_-30_0_-180_-1505.png',
#  'thm_dir_N-30_240_-30_0_-120_-9013.png',
#  'thm_dir_N-30_000_-30_0_0_309.png',
#  'thm_dir_N-30_120_-30_0_120_15016.png',
#  'thm_dir_N-30_030_-30_0_30_603.png',
#  'thm_dir_N-30_180_-30_0_-180_-15016.png',
#  'thm_dir_N00_060_0_30_60_9026.png',
#  'thm_dir_N-30_300_-30_0_-60_-3011.png',
#  'thm_dir_N00_300_0_30_-60_-3013.png',
#  'thm_dir_N-30_300_-30_0_-60_-309.png',
#  'thm_dir_N-30_300_-30_0_-60_-308.png',
#  'thm_dir_N00_300_0_30_-60_-3012.png',
#  'thm_dir_N-30_300_-30_0_-60_-3010.png',
#  'thm_dir_N00_060_0_30_60_9027.png',
#  'thm_dir_N-30_180_-30_0_-180_-15017.png',
#  'thm_dir_N-30_030_-30_0_30_602.png',
#  'thm_dir_N-30_000_-30_0_0_308.png',
#  'thm_dir_N-30_120_-30_0_120_15017.png',
#  'thm_dir_N-30_240_-30_0_-120_-9012.png',
#  'thm_dir_N-30_180_-30_0_-180_-1504.png',
#  'thm_dir_N-30_090_-30_0_90_12019.png',
#  'thm_dir_N-30_090_-30_0_90_12025.png',
#  'thm_dir_N-30_330_-30_0_-30_013.png',
#  'thm_dir_N00_210_0_30_-150_-12023.png',
#  'thm_dir_N-30_270_-30_0_-90_-6023.png',
#  'thm_dir_N-30_330_-30_0_-30_02.png',
#  'thm_dir_N00_030_0_30_30_601.png',
#  'thm_dir_N00_060_0_30_60_902.png',
#  'thm_dir_N00_030_0_30_30_6021.png',
#  'thm_dir_N00_240_0_30_-120_-907.png',
#  'thm_dir_N-30_270_-30_0_-90_-606.png',
#  'thm_dir_N-30_000_-30_0_0_3017.png',
#  'thm_dir_N00_300_0_30_-60_-302.png',
#  'thm_dir_N00_330_0_30_-30_07.png',
#  'thm_dir_N00_210_0_30_-150_-1202.png',
#  'thm_dir_N00_240_0_30_-120_-9016.png',
#  'thm_dir_N00_330_0_30_-30_015.png',
#  'thm_dir_N-30_030_-30_0_30_6021.png',
#  'thm_dir_N00_330_0_30_-30_029.png',
#  'thm_dir_N00_330_0_30_-30_028.png',
#  'thm_dir_N-30_030_-30_0_30_6020.png',
#  'thm_dir_N00_330_0_30_-30_014.png',
#  'thm_dir_N00_240_0_30_-120_-9017.png',
#  'thm_dir_N00_210_0_30_-150_-1203.png',
#  'thm_dir_N00_330_0_30_-30_06.png',
#  'thm_dir_N00_300_0_30_-60_-303.png',
#  'thm_dir_N-30_000_-30_0_0_3016.png',
#  'thm_dir_N00_240_0_30_-120_-906.png',
#  'thm_dir_N00_030_0_30_30_6020.png',
#  'thm_dir_N-30_270_-30_0_-90_-607.png',
#  'thm_dir_N00_060_0_30_60_903.png',
#  'thm_dir_N-30_330_-30_0_-30_03.png',
#  'thm_dir_N00_030_0_30_30_600.png',
#  'thm_dir_N-30_270_-30_0_-90_-6022.png',
#  'thm_dir_N00_210_0_30_-150_-12022.png',
#  'thm_dir_N-30_330_-30_0_-30_012.png',
#  'thm_dir_N-30_090_-30_0_90_12024.png',
#  'thm_dir_N-30_090_-30_0_90_12018.png',
#  'thm_dir_N-30_090_-30_0_90_12026.png',
#  'thm_dir_N-30_330_-30_0_-30_010.png',
#  'thm_dir_N-30_270_-30_0_-90_-6020.png',
#  'thm_dir_N00_210_0_30_-150_-12020.png',
#  'thm_dir_N00_030_0_30_30_602.png',
#  'thm_dir_N-30_330_-30_0_-30_01.png',
#  'thm_dir_N-30_270_-30_0_-90_-605.png',
#  'thm_dir_N00_030_0_30_30_6022.png',
#  'thm_dir_N00_240_0_30_-120_-904.png',
#  'thm_dir_N-30_000_-30_0_0_3028.png',
#  'thm_dir_N00_060_0_30_60_901.png',
#  'thm_dir_N00_300_0_30_-60_-301.png',
#  'thm_dir_N-30_000_-30_0_0_3014.png',
#  'thm_dir_N00_240_0_30_-120_-9029.png',
#  'thm_dir_N00_210_0_30_-150_-1201.png',
#  'thm_dir_N00_330_0_30_-30_04.png',
#  'thm_dir_N00_240_0_30_-120_-9015.png',
#  'thm_dir_N00_330_0_30_-30_016.png',
#  'thm_dir_N-30_030_-30_0_30_6022.png',
#  'thm_dir_N-30_030_-30_0_30_6023.png',
#  'thm_dir_N00_330_0_30_-30_017.png',
#  'thm_dir_N00_240_0_30_-120_-9014.png',
#  'thm_dir_N00_330_0_30_-30_05.png',
#  'thm_dir_N00_240_0_30_-120_-9028.png',
#  'thm_dir_N00_210_0_30_-150_-1200.png',
#  'thm_dir_N-30_000_-30_0_0_3015.png',
#  'thm_dir_N00_300_0_30_-60_-300.png',
#  'thm_dir_N00_060_0_30_60_900.png',
#  'thm_dir_N-30_000_-30_0_0_3029.png',
#  'thm_dir_N-30_270_-30_0_-90_-604.png',
#  'thm_dir_N00_240_0_30_-120_-905.png',
#  'thm_dir_N00_030_0_30_30_6023.png',
#  'thm_dir_N00_030_0_30_30_603.png',
#  'thm_dir_N-30_330_-30_0_-30_00.png',
#  'thm_dir_N00_210_0_30_-150_-12021.png',
#  'thm_dir_N-30_270_-30_0_-90_-6021.png',
#  'thm_dir_N-30_330_-30_0_-30_011.png',
#  'thm_dir_N-30_090_-30_0_90_12027.png',
#  'thm_dir_N-30_090_-30_0_90_12023.png',
#  'thm_dir_N-30_330_-30_0_-30_029.png',
#  'thm_dir_N-30_330_-30_0_-30_015.png',
#  'thm_dir_N-30_270_-30_0_-90_-6019.png',
#  'thm_dir_N00_210_0_30_-150_-12019.png',
#  'thm_dir_N-30_270_-30_0_-90_-6025.png',
#  'thm_dir_N00_210_0_30_-150_-12025.png',
#  'thm_dir_N-30_330_-30_0_-30_04.png',
#  'thm_dir_N00_030_0_30_30_607.png',
#  'thm_dir_N00_300_0_30_-60_-304.png',
#  'thm_dir_N-30_000_-30_0_0_3011.png',
#  'thm_dir_N00_030_0_30_30_6027.png',
#  'thm_dir_N00_240_0_30_-120_-901.png',
#  'thm_dir_N-30_270_-30_0_-90_-600.png',
#  'thm_dir_N00_060_0_30_60_904.png',
#  'thm_dir_N00_240_0_30_-120_-9010.png',
#  'thm_dir_N00_210_0_30_-150_-1204.png',
#  'thm_dir_N00_330_0_30_-30_01.png',
#  'thm_dir_N-30_030_-30_0_30_6027.png',
#  'thm_dir_N00_330_0_30_-30_013.png',
#  'thm_dir_N00_330_0_30_-30_012.png',
#  'thm_dir_N-30_030_-30_0_30_6026.png',
#  'thm_dir_N00_330_0_30_-30_00.png',
#  'thm_dir_N00_210_0_30_-150_-1205.png',
#  'thm_dir_N00_240_0_30_-120_-9011.png',
#  'thm_dir_N00_060_0_30_60_905.png',
#  'thm_dir_N00_240_0_30_-120_-900.png',
#  'thm_dir_N00_030_0_30_30_6026.png',
#  'thm_dir_N-30_270_-30_0_-90_-601.png',
#  'thm_dir_N-30_000_-30_0_0_3010.png',
#  'thm_dir_N00_300_0_30_-60_-305.png',
#  'thm_dir_N-30_330_-30_0_-30_05.png',
#  'thm_dir_N00_030_0_30_30_606.png',
#  'thm_dir_N00_210_0_30_-150_-12024.png',
#  'thm_dir_N-30_270_-30_0_-90_-6024.png',
#  'thm_dir_N00_210_0_30_-150_-12018.png',
#  'thm_dir_N-30_270_-30_0_-90_-6018.png',
#  'thm_dir_N-30_330_-30_0_-30_014.png',
#  'thm_dir_N-30_330_-30_0_-30_028.png',
#  'thm_dir_N-30_090_-30_0_90_12022.png',
#  'thm_dir_N-30_090_-30_0_90_12020.png',
#  'thm_dir_N-30_330_-30_0_-30_016.png',
#  'thm_dir_N00_210_0_30_-150_-12026.png',
#  'thm_dir_N-30_270_-30_0_-90_-6026.png',
#  'thm_dir_N00_030_0_30_30_604.png',
#  'thm_dir_N-30_330_-30_0_-30_07.png',
#  'thm_dir_N-30_090_-30_0_90_1208.png',
#  'thm_dir_N-30_000_-30_0_0_3012.png',
#  'thm_dir_N00_300_0_30_-60_-307.png',
#  'thm_dir_N00_030_0_30_30_6018.png',
#  'thm_dir_N00_060_0_30_60_907.png',
#  'thm_dir_N-30_270_-30_0_-90_-603.png',
#  'thm_dir_N00_030_0_30_30_6024.png',
#  'thm_dir_N00_240_0_30_-120_-902.png',
#  'thm_dir_N00_240_0_30_-120_-9013.png',
#  'thm_dir_N00_330_0_30_-30_02.png',
#  'thm_dir_N00_210_0_30_-150_-1207.png',
#  'thm_dir_N-30_030_-30_0_30_6024.png',
#  'thm_dir_N-30_030_-30_0_30_6018.png',
#  'thm_dir_N00_330_0_30_-30_010.png',
#  'thm_dir_N00_330_0_30_-30_011.png',
#  'thm_dir_N-30_030_-30_0_30_6019.png',
#  'thm_dir_N-30_030_-30_0_30_6025.png',
#  'thm_dir_N00_210_0_30_-150_-1206.png',
#  'thm_dir_N00_330_0_30_-30_03.png',
#  'thm_dir_N00_240_0_30_-120_-9012.png',
#  'thm_dir_N-30_270_-30_0_-90_-602.png',
#  'thm_dir_N00_240_0_30_-120_-903.png',
#  'thm_dir_N00_030_0_30_30_6025.png',
#  'thm_dir_N00_060_0_30_60_906.png',
#  'thm_dir_N00_300_0_30_-60_-306.png',
#  'thm_dir_N00_030_0_30_30_6019.png',
#  'thm_dir_N-30_000_-30_0_0_3013.png',
#  'thm_dir_N-30_090_-30_0_90_1209.png',
#  'thm_dir_N00_030_0_30_30_605.png',
#  'thm_dir_N-30_330_-30_0_-30_06.png',
#  'thm_dir_N-30_270_-30_0_-90_-6027.png',
#  'thm_dir_N00_210_0_30_-150_-12027.png',
#  'thm_dir_N-30_330_-30_0_-30_017.png',
#  'thm_dir_N-30_090_-30_0_90_12021.png',
#  'thm_dir_N-30_090_-30_0_90_12010.png',
#  'thm_dir_N-30_330_-30_0_-30_026.png',
#  'thm_dir_N-30_270_-30_0_-90_-6016.png',
#  'thm_dir_N00_210_0_30_-150_-12016.png',
#  'thm_dir_N00_030_0_30_30_608.png',
#  'thm_dir_N-30_090_-30_0_90_1204.png',
#  'thm_dir_N00_030_0_30_30_6014.png',
#  'thm_dir_N00_030_0_30_30_6028.png',
#  'thm_dir_N-30_000_-30_0_0_3022.png',
#  'thm_dir_N00_240_0_30_-120_-9023.png',
#  'thm_dir_N00_330_0_30_-30_020.png',
#  'thm_dir_N-30_030_-30_0_30_6028.png',
#  'thm_dir_N-30_030_-30_0_30_6014.png',
#  'thm_dir_N-30_030_-30_0_30_6015.png',
#  'thm_dir_N-30_030_-30_0_30_6029.png',
#  'thm_dir_N00_330_0_30_-30_021.png',
#  'thm_dir_N00_240_0_30_-120_-9022.png',
#  'thm_dir_N-30_000_-30_0_0_3023.png',
#  'thm_dir_N00_030_0_30_30_6029.png',
#  'thm_dir_N00_030_0_30_30_6015.png',
#  'thm_dir_N-30_090_-30_0_90_1205.png',
#  'thm_dir_N00_030_0_30_30_609.png',
#  'thm_dir_N00_210_0_30_-150_-12017.png',
#  'thm_dir_N-30_270_-30_0_-90_-6017.png',
#  'thm_dir_N-30_330_-30_0_-30_027.png',
#  'thm_dir_N-30_090_-30_0_90_12011.png',
#  'thm_dir_N-30_090_-30_0_90_12013.png',
#  'thm_dir_N-30_330_-30_0_-30_025.png',
#  'thm_dir_N-30_330_-30_0_-30_019.png',
#  'thm_dir_N00_210_0_30_-150_-12015.png',
#  'thm_dir_N-30_270_-30_0_-90_-6015.png',
#  'thm_dir_N00_210_0_30_-150_-12029.png',
#  'thm_dir_N-30_270_-30_0_-90_-6029.png',
#  'thm_dir_N-30_330_-30_0_-30_08.png',
#  'thm_dir_N-30_090_-30_0_90_1207.png',
#  'thm_dir_N00_030_0_30_30_6017.png',
#  'thm_dir_N00_300_0_30_-60_-308.png',
#  'thm_dir_N-30_000_-30_0_0_3021.png',
#  'thm_dir_N00_060_0_30_60_908.png',
#  'thm_dir_N00_210_0_30_-150_-1208.png',
#  'thm_dir_N00_240_0_30_-120_-9020.png',
#  'thm_dir_N00_330_0_30_-30_023.png',
#  'thm_dir_N-30_030_-30_0_30_6017.png',
#  'thm_dir_N-30_030_-30_0_30_6016.png',
#  'thm_dir_N00_330_0_30_-30_022.png',
#  'thm_dir_N00_210_0_30_-150_-1209.png',
#  'thm_dir_N00_240_0_30_-120_-9021.png',
#  'thm_dir_N00_060_0_30_60_909.png',
#  'thm_dir_N-30_000_-30_0_0_3020.png',
#  'thm_dir_N00_030_0_30_30_6016.png',
#  'thm_dir_N00_300_0_30_-60_-309.png',
#  'thm_dir_N-30_090_-30_0_90_1206.png',
#  'thm_dir_N-30_330_-30_0_-30_09.png',
#  'thm_dir_N-30_270_-30_0_-90_-6028.png',
#  'thm_dir_N00_210_0_30_-150_-12028.png',
#  'thm_dir_N-30_270_-30_0_-90_-6014.png',
#  'thm_dir_N00_210_0_30_-150_-12014.png',
#  'thm_dir_N-30_330_-30_0_-30_018.png',
#  'thm_dir_N-30_330_-30_0_-30_024.png',
#  'thm_dir_N-30_090_-30_0_90_12012.png',
#  'thm_dir_N-30_090_-30_0_90_12016.png',
#  'thm_dir_N-30_330_-30_0_-30_020.png',
#  'thm_dir_N00_210_0_30_-150_-12010.png',
#  'thm_dir_N-30_270_-30_0_-90_-6010.png',
#  'thm_dir_N-30_090_-30_0_90_1202.png',
#  'thm_dir_N-30_000_-30_0_0_3024.png',
#  'thm_dir_N-30_270_-30_0_-90_-609.png',
#  'thm_dir_N00_240_0_30_-120_-908.png',
#  'thm_dir_N-30_000_-30_0_0_3018.png',
#  'thm_dir_N00_030_0_30_30_6012.png',
#  'thm_dir_N00_330_0_30_-30_08.png',
#  'thm_dir_N00_240_0_30_-120_-9025.png',
#  'thm_dir_N00_240_0_30_-120_-9019.png',
#  'thm_dir_N-30_030_-30_0_30_6012.png',
#  'thm_dir_N00_330_0_30_-30_026.png',
#  'thm_dir_N00_330_0_30_-30_027.png',
#  'thm_dir_N-30_030_-30_0_30_6013.png',
#  'thm_dir_N00_240_0_30_-120_-9018.png',
#  'thm_dir_N00_240_0_30_-120_-9024.png',
#  'thm_dir_N00_330_0_30_-30_09.png',
#  'thm_dir_N00_030_0_30_30_6013.png',
#  'thm_dir_N-30_000_-30_0_0_3019.png',
#  'thm_dir_N-30_270_-30_0_-90_-608.png',
#  'thm_dir_N00_240_0_30_-120_-909.png',
#  'thm_dir_N-30_000_-30_0_0_3025.png',
#  'thm_dir_N-30_090_-30_0_90_1203.png',
#  'thm_dir_N-30_270_-30_0_-90_-6011.png',
#  'thm_dir_N00_210_0_30_-150_-12011.png',
#  'thm_dir_N-30_330_-30_0_-30_021.png',
#  'thm_dir_N-30_090_-30_0_90_12017.png',
#  'thm_dir_N-30_090_-30_0_90_12015.png',
#  'thm_dir_N-30_090_-30_0_90_12029.png',
#  'thm_dir_N-30_330_-30_0_-30_023.png',
#  'thm_dir_N-30_270_-30_0_-90_-6013.png',
#  'thm_dir_N00_210_0_30_-150_-12013.png',
#  'thm_dir_N-30_090_-30_0_90_1201.png',
#  'thm_dir_N-30_000_-30_0_0_3027.png',
#  'thm_dir_N00_030_0_30_30_6011.png',
#  'thm_dir_N00_240_0_30_-120_-9026.png',
#  'thm_dir_N00_330_0_30_-30_019.png',
#  'thm_dir_N-30_030_-30_0_30_6011.png',
#  'thm_dir_N00_330_0_30_-30_025.png',
#  'thm_dir_N00_330_0_30_-30_024.png',
#  'thm_dir_N-30_030_-30_0_30_6010.png',
#  'thm_dir_N00_330_0_30_-30_018.png',
#  'thm_dir_N00_240_0_30_-120_-9027.png',
#  'thm_dir_N00_030_0_30_30_6010.png',
#  'thm_dir_N-30_000_-30_0_0_3026.png',
#  'thm_dir_N-30_090_-30_0_90_1200.png',
#  'thm_dir_N00_210_0_30_-150_-12012.png',
#  'thm_dir_N-30_270_-30_0_-90_-6012.png',
#  'thm_dir_N-30_330_-30_0_-30_022.png',
#  'thm_dir_N-30_090_-30_0_90_12028.png',
#  'thm_dir_N-30_090_-30_0_90_12014.png',
#  'thm_dir_N-30_180_-30_0_-180_-1509.png',
#  'thm_dir_N-30_240_-30_0_-120_-9023.png',
#  'thm_dir_N-30_120_-30_0_120_1507.png',
#  'thm_dir_N-30_000_-30_0_0_305.png',
#  '.ipynb_checkpoints',
#  'thm_dir_N-30_120_-30_0_120_15026.png',
#  'thm_dir_N-30_180_-30_0_-180_-15026.png',
#  'thm_dir_N00_060_0_30_60_9016.png',
#  'thm_dir_N-30_300_-30_0_-60_-3021.png',
#  'thm_dir_N-30_240_-30_0_-120_-900.png',
#  'thm_dir_N00_300_0_30_-60_-3023.png',
#  'thm_dir_N-30_300_-30_0_-60_-305.png',
#  'thm_dir_N-30_300_-30_0_-60_-304.png',
#  'thm_dir_N00_300_0_30_-60_-3022.png',
#  'thm_dir_N-30_240_-30_0_-120_-901.png',
#  'thm_dir_N-30_300_-30_0_-60_-3020.png',
#  'thm_dir_N00_060_0_30_60_9017.png',
#  'thm_dir_N-30_180_-30_0_-180_-15027.png',
#  'thm_dir_N-30_120_-30_0_120_15027.png',
#  'thm_dir_N-30_000_-30_0_0_304.png',
#  'thm_dir_N-30_120_-30_0_120_1506.png',
#  'thm_dir_N-30_240_-30_0_-120_-9022.png',
#  'thm_dir_N-30_180_-30_0_-180_-1508.png',
#  'thm_dir_N-30_240_-30_0_-120_-9020.png',
#  'thm_dir_N-30_120_-30_0_120_1504.png',
#  'thm_dir_N-30_120_-30_0_120_15019.png',
#  'thm_dir_N-30_000_-30_0_0_306.png',
#  'thm_dir_N-30_120_-30_0_120_15025.png',
#  'thm_dir_N-30_180_-30_0_-180_-15025.png',
#  'thm_dir_N00_060_0_30_60_9015.png',
#  'thm_dir_N00_060_0_30_60_9029.png',
#  'thm_dir_N-30_180_-30_0_-180_-15019.png',
#  'thm_dir_N-30_300_-30_0_-60_-3022.png',
#  'thm_dir_N-30_240_-30_0_-120_-903.png',
#  'thm_dir_N-30_300_-30_0_-60_-306.png',
#  'thm_dir_N00_300_0_30_-60_-3020.png',
#  'thm_dir_N00_300_0_30_-60_-3021.png',
#  'thm_dir_N-30_300_-30_0_-60_-307.png',
#  'thm_dir_N-30_240_-30_0_-120_-902.png',
#  'thm_dir_N-30_300_-30_0_-60_-3023.png',
#  'thm_dir_N-30_180_-30_0_-180_-15018.png',
#  'thm_dir_N00_060_0_30_60_9028.png',
#  'thm_dir_N00_060_0_30_60_9014.png',
#  'thm_dir_N-30_180_-30_0_-180_-15024.png',
#  'thm_dir_N-30_120_-30_0_120_15024.png',
#  'thm_dir_N-30_120_-30_0_120_15018.png',
#  'thm_dir_N-30_000_-30_0_0_307.png',
#  'thm_dir_N-30_120_-30_0_120_1505.png',
#  'thm_dir_N-30_240_-30_0_-120_-9021.png',
#  'thm_dir_N-30_240_-30_0_-120_-9019.png',
#  'thm_dir_N-30_240_-30_0_-120_-9025.png',
#  'thm_dir_N-30_120_-30_0_120_1501.png',
#  'thm_dir_N-30_030_-30_0_30_609.png',
#  'thm_dir_N-30_120_-30_0_120_15020.png',
#  'thm_dir_N-30_000_-30_0_0_303.png',
#  'thm_dir_N-30_180_-30_0_-180_-15020.png',
#  'thm_dir_N00_060_0_30_60_9010.png',
#  'thm_dir_N-30_240_-30_0_-120_-906.png',
#  'thm_dir_N-30_300_-30_0_-60_-3027.png',
#  'thm_dir_N-30_300_-30_0_-60_-303.png',
#  'thm_dir_N00_300_0_30_-60_-3025.png',
#  'thm_dir_N00_300_0_30_-60_-3019.png',
#  'thm_dir_N00_300_0_30_-60_-3018.png',
#  'thm_dir_N00_300_0_30_-60_-3024.png',
#  'thm_dir_N-30_300_-30_0_-60_-302.png',
#  'thm_dir_N-30_300_-30_0_-60_-3026.png',
#  'thm_dir_N-30_240_-30_0_-120_-907.png',
#  'thm_dir_N00_060_0_30_60_9011.png',
#  'thm_dir_N-30_180_-30_0_-180_-15021.png',
#  'thm_dir_N-30_000_-30_0_0_302.png',
#  'thm_dir_N-30_120_-30_0_120_15021.png',
#  'thm_dir_N-30_030_-30_0_30_608.png',
#  'thm_dir_N-30_120_-30_0_120_1500.png',
#  'thm_dir_N-30_240_-30_0_-120_-9024.png',
#  'thm_dir_N-30_240_-30_0_-120_-9018.png',
#  'thm_dir_N-30_240_-30_0_-120_-9026.png',
#  'thm_dir_N-30_120_-30_0_120_1502.png',
#  'thm_dir_N-30_120_-30_0_120_15023.png',
#  'thm_dir_N-30_000_-30_0_0_300.png',
#  'thm_dir_N-30_180_-30_0_-180_-15023.png',
#  'thm_dir_N00_060_0_30_60_9013.png',
#  'thm_dir_N-30_300_-30_0_-60_-3018.png',
#  'thm_dir_N-30_240_-30_0_-120_-905.png',
#  'thm_dir_N-30_300_-30_0_-60_-3024.png',
#  'thm_dir_N00_300_0_30_-60_-3026.png',
#  'thm_dir_N-30_300_-30_0_-60_-300.png',
#  'thm_dir_N-30_300_-30_0_-60_-301.png',
#  'thm_dir_N00_300_0_30_-60_-3027.png',
#  'thm_dir_N-30_300_-30_0_-60_-3025.png',
#  'thm_dir_N-30_240_-30_0_-120_-904.png',
#  'thm_dir_N-30_300_-30_0_-60_-3019.png',
#  'thm_dir_N00_060_0_30_60_9012.png',
#  'thm_dir_N-30_180_-30_0_-180_-15022.png',
#  'thm_dir_N-30_000_-30_0_0_301.png',
#  'thm_dir_N-30_120_-30_0_120_15022.png',
#  'thm_dir_N-30_120_-30_0_120_1503.png',
#  'thm_dir_N-30_240_-30_0_-120_-9027.png']

# %%
from keras import backend as K
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred[0])
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def loss_fn(y_true, y_pred):
    # y_pred = tf.expand_dims(y_pred, axis=-1)
    # print(y_pred.shape)
    # print(y_true.shape)
    # loss0 = tf.nn.weighted_cross_entropy_with_logits(y_true, y_pred[0], pos_weight=2, name=None)
    # loss1 = tf.nn.weighted_cross_entropy_with_logits(y_true, y_pred[1], pos_weight=2, name=None)
    # loss2 = tf.nn.weighted_cross_entropy_with_logits(y_true, y_pred[2], pos_weight=2, name=None)
    # loss3 = tf.nn.weighted_cross_entropy_with_logits(y_true, y_pred[3], pos_weight=2, name=None)
    # loss4 = tf.nn.weighted_cross_entropy_with_logits(y_true, y_pred[4], pos_weight=2, name=None)
    # loss5 = tf.nn.weighted_cross_entropy_with_logits(y_true, y_pred[5], pos_weight=2, name=None)
    # loss6 = tf.nn.weighted_cross_entropy_with_logits(y_true, y_pred[6], pos_weight=2, name=None)

    loss0 = bce(y_true, y_pred[0])
    loss1 = bce(y_true, y_pred[1])
    loss2 = bce(y_true, y_pred[2])
    loss3 = bce(y_true, y_pred[3])
    loss4 = bce(y_true, y_pred[4])
    loss5 = bce(y_true, y_pred[5])
    loss6 = bce(y_true, y_pred[6])
    return loss0 + loss1 + loss2 + loss3 + loss4 + loss5 + loss6

def REBNCONV(x, out_ch=3, dirate=1):
    #x = ZeroPadding2D((1*dirate,1*dirate))(x)
    x = Conv2D(out_ch, 3, padding='same', dilation_rate = 1*dirate)(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    return x

def _upsample_like(src, tar):
    h = int(tar.shape[1]/src.shape[1])
    w = int(tar.shape[2]/src.shape[2])
    src = UpSampling2D((h,w), interpolation='bilinear')(src)
    return src

def RSU7(x, mid_ch=12, out_ch=3):
    
    x0 = REBNCONV(x, out_ch, 1)
    
    x1 = REBNCONV(x0, mid_ch, 1)
    x = MaxPool2D(2, 2)(x1)

    x2 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x2)

    x3 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x3)

    x4 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x4)

    x5 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x5)

    x6 = REBNCONV(x, mid_ch, 1)

    x = REBNCONV(x6, mid_ch, 2)

    x = REBNCONV(tf.concat([x,x6],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x5)

    x = REBNCONV(tf.concat([x,x5],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x4)

    x = REBNCONV(tf.concat([x,x4],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x3)

    x = REBNCONV(tf.concat([x,x3],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x2)

    x = REBNCONV(tf.concat([x,x2],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x1)

    x = REBNCONV(tf.concat([x,x1],axis=-1), out_ch, 1)

    return x + x0

def RSU6(x, mid_ch=12, out_ch=3):
    
    x0 = REBNCONV(x, out_ch, 1)
    
    x1 = REBNCONV(x0, mid_ch, 1)
    x = MaxPool2D(2, 2)(x1)

    x2 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x2)

    x3 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x3)

    x4 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x4)

    x5 = REBNCONV(x, mid_ch, 1)

    x = REBNCONV(x, mid_ch, 2)

    x = REBNCONV(tf.concat([x,x5],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x4)

    x = REBNCONV(tf.concat([x,x4],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x3)

    x = REBNCONV(tf.concat([x,x3],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x2)

    x = REBNCONV(tf.concat([x,x2],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x1)

    x = REBNCONV(tf.concat([x,x1],axis=-1), out_ch, 1)

    return x + x0

def RSU5(x, mid_ch=12, out_ch=3):
    
    x0 = REBNCONV(x, out_ch, 1)
    
    x1 = REBNCONV(x0, mid_ch, 1)
    x = MaxPool2D(2, 2)(x1)

    x2 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x2)

    x3 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x3)

    x4 = REBNCONV(x, mid_ch, 1)

    x = REBNCONV(x, mid_ch, 2)

    x = REBNCONV(tf.concat([x,x4],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x3)

    x = REBNCONV(tf.concat([x,x3],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x2)

    x = REBNCONV(tf.concat([x,x2],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x1)

    x = REBNCONV(tf.concat([x,x1],axis=-1), out_ch, 1)

    return x + x0

def RSU4(x, mid_ch=12, out_ch=3):
    
    x0 = REBNCONV(x, out_ch, 1)
    
    x1 = REBNCONV(x0, mid_ch, 1)
    x = MaxPool2D(2, 2)(x1)

    x2 = REBNCONV(x, mid_ch, 1)
    x = MaxPool2D(2, 2)(x2)

    x3 = REBNCONV(x, mid_ch, 1)

    x = REBNCONV(x, mid_ch, 2)

    x = REBNCONV(tf.concat([x,x3],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x2)

    x = REBNCONV(tf.concat([x,x2],axis=-1), mid_ch, 1)
    x = _upsample_like(x,x1)

    x = REBNCONV(tf.concat([x,x1],axis=-1), out_ch, 1)

    return x + x0

def RSU4F(x, mid_ch=12, out_ch=3):

    x0 = REBNCONV(x, out_ch, 1)
    
    x1 = REBNCONV(x0, mid_ch, 1)
    x2 = REBNCONV(x1, mid_ch, 2)
    x3 = REBNCONV(x2, mid_ch, 4)
    
    x4 = REBNCONV(x3, mid_ch, 8)
    
    x = REBNCONV(tf.concat([x4,x3],axis=-1), mid_ch, 4)
    x = REBNCONV(tf.concat([x,x2],axis=-1), mid_ch, 2)
    x = REBNCONV(tf.concat([x,x1],axis=-1), out_ch, 1)

    return x + x0

def U2NET(x, out_ch=1):
    
    x1 = RSU7(x, 32, 64)
    x = MaxPool2D(2, 2)(x1)

    x2 = RSU6(x, 32, 128)
    x = MaxPool2D(2, 2)(x2)

    x3 = RSU5(x, 64, 256)
    x = MaxPool2D(2, 2)(x3)

    x4 = RSU4(x, 128, 512)
    x = MaxPool2D(2, 2)(x4)

    x5 = RSU4F(x, 256, 512)
    x = MaxPool2D(2, 2)(x5)

    x6 = RSU4F(x, 256, 512)
    x = _upsample_like(x6,x5)

    #-----------------decoder--------------------#

    x5 = RSU4F(tf.concat([x,x5],axis=-1),256, 512)
    x = _upsample_like(x5,x4)

    x4 = RSU4(tf.concat([x,x4],axis=-1),128, 256)
    x = _upsample_like(x4,x3)

    x3 = RSU5(tf.concat([x,x3],axis=-1),64, 128)
    x = _upsample_like(x3,x2)

    x2 = RSU6(tf.concat([x,x2],axis=-1),32, 64)
    x = _upsample_like(x2,x1)
    
    x1 = RSU7(tf.concat([x,x1],axis=-1),16, 64)

    #Side output
    x = ZeroPadding2D((1,1))(x1) 
    d1 = Conv2D(out_ch, 3)(x)
    d1 = Activation('sigmoid')(d1)

    x = ZeroPadding2D((1,1))(x2) 
    x = Conv2D(out_ch, 3)(x)
    d2 = _upsample_like(x,d1)
    d2 = Activation('sigmoid')(d2)
    
    x = ZeroPadding2D((1,1))(x3) 
    x = Conv2D(out_ch, 3)(x)
    d3 = _upsample_like(x,d1)
    d3 = Activation('sigmoid')(d3)
    
    x = ZeroPadding2D((1,1))(x4) 
    x = Conv2D(out_ch, 3)(x)
    d4 = _upsample_like(x,d1)
    d4 = Activation('sigmoid')(d4)
    
    x = ZeroPadding2D((1,1))(x5) 
    x = Conv2D(out_ch, 3)(x)
    d5 = _upsample_like(x,d1)
    d5 = Activation('sigmoid')(d5)
    
    x = ZeroPadding2D((1,1))(x6) 
    x = Conv2D(out_ch, 3)(x)
    d6 = _upsample_like(x,d1)
    d6 = Activation('sigmoid')(d6)

    d0 = Conv2D(out_ch, 1)(tf.concat([d1,d2,d3,d4,d5,d6],axis=-1))
    d0 = Activation('sigmoid')(d0)

    return tf.stack([d0,d1,d2,d3,d4,d5,d6])

def U2NETP(x, out_ch=1):
    
    x1 = RSU7(x, 16, 64)
    x = MaxPool2D(2, 2)(x1)

    x2 = RSU6(x, 16, 64)
    x = MaxPool2D(2, 2)(x2)

    x3 = RSU5(x, 16, 64)
    x = MaxPool2D(2, 2)(x3)

    x4 = RSU4(x, 16, 64)
    x = MaxPool2D(2, 2)(x4)

    x5 = RSU4F(x, 16, 64)
    x = MaxPool2D(2, 2)(x5)

    x6 = RSU4F(x, 16, 64)
    x = _upsample_like(x6,x5)

    #---------------decoder--------------------
    x5 = RSU4F(tf.concat([x,x5],axis=-1),16, 64)
    x = _upsample_like(x5,x4)

    x4 = RSU4(tf.concat([x,x4],axis=-1),16, 64)
    x = _upsample_like(x4,x3)

    x3 = RSU5(tf.concat([x,x3],axis=-1),16, 64)
    x = _upsample_like(x3,x2)

    x2 = RSU6(tf.concat([x,x2],axis=-1),16, 64)
    x = _upsample_like(x2,x1)
    
    x1 = RSU7(tf.concat([x,x1],axis=-1),16, 64)

    x = ZeroPadding2D((1,1))(x1) 
    d1 = Conv2D(out_ch, 3)(x)
    d1 = Activation('sigmoid')(d1)

    x = ZeroPadding2D((1,1))(x2) 
    x = Conv2D(out_ch, 3)(x)
    d2 = _upsample_like(x,d1)
    d2 = Activation('sigmoid')(d2)
    
    x = ZeroPadding2D((1,1))(x3) 
    x = Conv2D(out_ch, 3)(x)
    d3 = _upsample_like(x,d1)
    d3 = Activation('sigmoid')(d3)
    
    x = ZeroPadding2D((1,1))(x4) 
    x = Conv2D(out_ch, 3)(x)
    d4 = _upsample_like(x,d1)
    d4 = Activation('sigmoid')(d4)
    
    x = ZeroPadding2D((1,1))(x5) 
    x = Conv2D(out_ch, 3)(x)
    d5 = _upsample_like(x,d1)
    d5 = Activation('sigmoid')(d5)
    
    x = ZeroPadding2D((1,1))(x6) 
    x = Conv2D(out_ch, 3)(x)
    d6 = _upsample_like(x,d1)
    d6 = Activation('sigmoid')(d6)

    d0 = Conv2D(out_ch, 1)(tf.concat([d1,d2,d3,d4,d5,d6],axis=-1))
    d0 = Activation('sigmoid')(d0)

    return tf.stack([d0,d1,d2,d3,d4,d5,d6]) 

net_input = Input(shape=(256,256,1)) 

model_output = U2NETP(net_input)

model = Model(inputs = net_input, outputs = model_output)

lr = 1e-3

opt = tf.keras.optimizers.Adam(learning_rate = lr)

bce = BinaryCrossentropy()

model.compile(optimizer = opt, loss = loss_fn, metrics = [dice_coef])
# Out:
# 2023-04-06 12:34:28.126419: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  9232        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 16  2320        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)  0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 16)   2320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   2320        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 16)  0           ['activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 16)   2320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 16, 16, 16)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 16)    0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 16)     2320        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 16)    64          ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 8, 8, 16)     0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 16)     2320        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 16)    64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 8, 8, 16)     0           ['batch_normalization_7[0][0]']
#
#  tf.concat (TFOpLambda)         (None, 8, 8, 32)     0           ['activation_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 16)     4624        ['tf.concat[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 16)    64          ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 16)     0           ['batch_normalization_8[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 16)   0           ['activation_8[0][0]']
#
#  tf.concat_1 (TFOpLambda)       (None, 16, 16, 32)   0           ['up_sampling2d[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 16)   4624        ['tf.concat_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 16)   0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 16)  0           ['activation_9[0][0]']
#
#  tf.concat_2 (TFOpLambda)       (None, 32, 32, 32)   0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   4624        ['tf.concat_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_10[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 16)  0           ['activation_10[0][0]']
#
#  tf.concat_3 (TFOpLambda)       (None, 64, 64, 32)   0           ['up_sampling2d_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 16)   4624        ['tf.concat_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 16  0          ['activation_11[0][0]']
#                                 )
#
#  tf.concat_4 (TFOpLambda)       (None, 128, 128, 32  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 16  4624        ['tf.concat_4[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 16  64         ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 16  0          ['activation_12[0][0]']
#                                 )
#
#  tf.concat_5 (TFOpLambda)       (None, 256, 256, 32  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  18496       ['tf.concat_5[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  tf.__operators__.add (TFOpLamb  (None, 256, 256, 64  0          ['activation_13[0][0]',
#  da)                            )                                 'activation[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 64  0          ['tf.__operators__.add[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  36928       ['max_pooling2d_5[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 64  256        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 16  9232        ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 16  64         ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 16)  0           ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 16)   2320        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_16[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   2320        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 16)  0           ['activation_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 16)   2320        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_18[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 8, 8, 16)    0           ['activation_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_9[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_9[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 16)    64          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 16)    64          ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_20[0][0]']
#
#  activation_19 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_19[0][0]']
#
#  tf.concat_6 (TFOpLambda)       (None, 8, 8, 32)     0           ['activation_20[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 16)     4624        ['tf.concat_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 16)    64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_21[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 16, 16, 16)  0           ['activation_21[0][0]']
#
#  tf.concat_7 (TFOpLambda)       (None, 16, 16, 32)   0           ['up_sampling2d_5[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 16)   4624        ['tf.concat_7[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 16)  64          ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_22[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 16)  0           ['activation_22[0][0]']
#
#  tf.concat_8 (TFOpLambda)       (None, 32, 32, 32)   0           ['up_sampling2d_6[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 16)   4624        ['tf.concat_8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_23[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 16)  0           ['activation_23[0][0]']
#
#  tf.concat_9 (TFOpLambda)       (None, 64, 64, 32)   0           ['up_sampling2d_7[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 16)   4624        ['tf.concat_9[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_24[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 16  0          ['activation_24[0][0]']
#                                 )
#
#  tf.concat_10 (TFOpLambda)      (None, 128, 128, 32  0           ['up_sampling2d_8[0][0]',
#                                 )                                 'activation_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  18496       ['tf.concat_10[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 64  256        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  tf.__operators__.add_1 (TFOpLa  (None, 128, 128, 64  0          ['activation_25[0][0]',
#  mbda)                          )                                 'activation_14[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 64, 64, 64)  0           ['tf.__operators__.add_1[0][0]']
#  )
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 64)   36928       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 16)   9232        ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_27[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 32, 32, 16)  0           ['activation_27[0][0]']
#  )
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 16)   2320        ['max_pooling2d_11[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 16)  64          ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_28[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 16, 16, 16)  0           ['activation_28[0][0]']
#  )
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 16)   2320        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_29[0][0]']
#  )
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_13[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 16)    64          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 16)    64          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_31[0][0]']
#
#  activation_30 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_30[0][0]']
#
#  tf.concat_11 (TFOpLambda)      (None, 8, 8, 32)     0           ['activation_31[0][0]',
#                                                                   'activation_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 16)     4624        ['tf.concat_11[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 16)    64          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_32[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 16, 16, 16)  0           ['activation_32[0][0]']
#
#  tf.concat_12 (TFOpLambda)      (None, 16, 16, 32)   0           ['up_sampling2d_9[0][0]',
#                                                                   'activation_29[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 16)   4624        ['tf.concat_12[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 16)  64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_33[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_33[0][0]']
#  )
#
#  tf.concat_13 (TFOpLambda)      (None, 32, 32, 32)   0           ['up_sampling2d_10[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 16)   4624        ['tf.concat_13[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 16)  64          ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_34[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 64, 64, 16)  0           ['activation_34[0][0]']
#  )
#
#  tf.concat_14 (TFOpLambda)      (None, 64, 64, 32)   0           ['up_sampling2d_11[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 64)   18496       ['tf.concat_14[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_35[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 64, 64, 64)  0           ['activation_35[0][0]',
#  mbda)                                                            'activation_26[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 32, 32, 64)  0           ['tf.__operators__.add_2[0][0]']
#  )
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 64)   36928       ['max_pooling2d_14[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 16)  64          ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_37[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 16, 16, 16)  0           ['activation_37[0][0]']
#  )
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 16)   2320        ['max_pooling2d_15[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 16)  64          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_38[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_38[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_16[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 16)    64          ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 16)    64          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_40[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_39[0][0]']
#
#  tf.concat_15 (TFOpLambda)      (None, 8, 8, 32)     0           ['activation_40[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 16)     4624        ['tf.concat_15[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 16)    64          ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_41[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_41[0][0]']
#  )
#
#  tf.concat_16 (TFOpLambda)      (None, 16, 16, 32)   0           ['up_sampling2d_12[0][0]',
#                                                                   'activation_38[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 16)   4624        ['tf.concat_16[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 16)  64          ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_42[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_42[0][0]']
#  )
#
#  tf.concat_17 (TFOpLambda)      (None, 32, 32, 32)   0           ['up_sampling2d_13[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 64)   18496       ['tf.concat_17[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_43[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 32, 32, 64)  0           ['activation_43[0][0]',
#  mbda)                                                            'activation_36[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 16, 16, 64)  0           ['tf.__operators__.add_3[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 64)   36928       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_44[0][0]']
#
# ...
#  tf.concat_44 (TFOpLambda)      (None, 8, 8, 32)     0           ['activation_105[0][0]',
#                                                                   'activation_104[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 8, 8, 16)     4624        ['tf.concat_44[0][0]']
#
#  batch_normalization_106 (Batch  (None, 8, 8, 16)    64          ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_106[0][0]']
#
#  up_sampling2d_28 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_106[0][0]']
#  )
#
#  tf.concat_45 (TFOpLambda)      (None, 16, 16, 32)   0           ['up_sampling2d_28[0][0]',
#                                                                   'activation_103[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 16, 16, 16)   4624        ['tf.concat_45[0][0]']
#
#  batch_normalization_107 (Batch  (None, 16, 16, 16)  64          ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 16, 16, 16)   0           ['batch_normalization_107[0][0]']
#
#  up_sampling2d_29 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_107[0][0]']
#  )
#
#  tf.concat_46 (TFOpLambda)      (None, 32, 32, 32)   0           ['up_sampling2d_29[0][0]',
#                                                                   'activation_102[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 32, 32, 16)   4624        ['tf.concat_46[0][0]']
#
#  batch_normalization_108 (Batch  (None, 32, 32, 16)  64          ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_108[0][0]']
#
#  up_sampling2d_30 (UpSampling2D  (None, 64, 64, 16)  0           ['activation_108[0][0]']
#  )
#
#  tf.concat_47 (TFOpLambda)      (None, 64, 64, 32)   0           ['up_sampling2d_30[0][0]',
#                                                                   'activation_101[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 64, 64, 16)   4624        ['tf.concat_47[0][0]']
#
#  batch_normalization_109 (Batch  (None, 64, 64, 16)  64          ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_109[0][0]']
#
#  up_sampling2d_31 (UpSampling2D  (None, 128, 128, 16  0          ['activation_109[0][0]']
#  )                              )
#
#  tf.concat_48 (TFOpLambda)      (None, 128, 128, 32  0           ['up_sampling2d_31[0][0]',
#                                 )                                 'activation_100[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 128, 128, 16  4624        ['tf.concat_48[0][0]']
#                                 )
#
#  batch_normalization_110 (Batch  (None, 128, 128, 16  64         ['conv2d_110[0][0]']
#  Normalization)                 )
#
#  activation_110 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_110[0][0]']
#                                 )
#
#  up_sampling2d_32 (UpSampling2D  (None, 256, 256, 16  0          ['activation_110[0][0]']
#  )                              )
#
#  tf.concat_49 (TFOpLambda)      (None, 256, 256, 32  0           ['up_sampling2d_32[0][0]',
#                                 )                                 'activation_99[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 256, 256, 64  18496       ['tf.concat_49[0][0]']
#                                 )
#
#  batch_normalization_111 (Batch  (None, 256, 256, 64  256        ['conv2d_111[0][0]']
#  Normalization)                 )
#
#  activation_111 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_111[0][0]']
#                                 )
#
#  tf.__operators__.add_10 (TFOpL  (None, 256, 256, 64  0          ['activation_111[0][0]',
#  ambda)                         )                                 'activation_98[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 130, 130, 64  0          ['tf.__operators__.add_9[0][0]']
#  D)                             )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 66, 66, 64)  0           ['tf.__operators__.add_8[0][0]']
#  D)
#
#  zero_padding2d_3 (ZeroPadding2  (None, 34, 34, 64)  0           ['tf.__operators__.add_7[0][0]']
#  D)
#
#  zero_padding2d_4 (ZeroPadding2  (None, 18, 18, 64)  0           ['tf.__operators__.add_6[0][0]']
#  D)
#
#  zero_padding2d_5 (ZeroPadding2  (None, 10, 10, 64)  0           ['tf.__operators__.add_5[0][0]']
#  D)
#
#  zero_padding2d (ZeroPadding2D)  (None, 258, 258, 64  0          ['tf.__operators__.add_10[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 128, 128, 1)  577         ['zero_padding2d_1[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 64, 64, 1)    577         ['zero_padding2d_2[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 32, 32, 1)    577         ['zero_padding2d_3[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 16, 16, 1)    577         ['zero_padding2d_4[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 8, 8, 1)      577         ['zero_padding2d_5[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 256, 256, 1)  577         ['zero_padding2d[0][0]']
#
#  up_sampling2d_33 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_113[0][0]']
#  )
#
#  up_sampling2d_34 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_114[0][0]']
#  )
#
#  up_sampling2d_35 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_115[0][0]']
#  )
#
#  up_sampling2d_36 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_116[0][0]']
#  )
#
#  up_sampling2d_37 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_117[0][0]']
#  )
#
#  activation_112 (Activation)    (None, 256, 256, 1)  0           ['conv2d_112[0][0]']
#
#  activation_113 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_33[0][0]']
#
#  activation_114 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_34[0][0]']
#
#  activation_115 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_35[0][0]']
#
#  activation_116 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_36[0][0]']
#
#  activation_117 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_37[0][0]']
#
#  tf.concat_50 (TFOpLambda)      (None, 256, 256, 6)  0           ['activation_112[0][0]',
#                                                                   'activation_113[0][0]',
#                                                                   'activation_114[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_116[0][0]',
#                                                                   'activation_117[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 256, 256, 1)  7           ['tf.concat_50[0][0]']
#
#  activation_118 (Activation)    (None, 256, 256, 1)  0           ['conv2d_118[0][0]']
#
#  tf.stack (TFOpLambda)          (7, None, 256, 256,  0           ['activation_118[0][0]',
#                                  1)                               'activation_112[0][0]',
#                                                                   'activation_113[0][0]',
#                                                                   'activation_114[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_116[0][0]',
#                                                                   'activation_117[0][0]']
#
# ==================================================================================================
# Total params: 1,135,725
# Trainable params: 1,130,029
# Non-trainable params: 5,696
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import Sequence
import numpy as np   
import cv2
import os
from glob import glob

class Mygenerator(Sequence):
    def __init__(self, x_set, y_set, batch_size):
        self.x, self.y = glob(x_set+'/*'), glob(y_set+'/*')
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

        # read your data here using the batch lists, batch_x and batch_y
        x = []
        y = []
        for filename in batch_x:
            # print(filename)
            img = cv2.imread(filename,0)
            img = cv2.resize(img,(256,256))
            img = img/255
            x.append(img)

        for filename in batch_y:
            img = cv2.imread(filename,0)
            img = cv2.resize(img,(256,256))
            img = np.where(img>0, 1, 0).astype(img.dtype)
            y.append(img)
        
        return np.array(x), np.array(y)

# %%
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau
# tr_img,tr_mask = gen('train')
# t_gen = zip(tr_img,tr_mask)
# vl_img,vl_mask = gen('val')
# vl_gen = zip(vl_img,vl_mask)

# checkpoint = ModelCheckpoint(
#     'modelu2netp.h5', 
#     monitor='val_loss', 
#     verbose=0, 
#     save_best_only=True, 
#     save_weights_only=False,
#     mode='auto'

# )
train = Mygenerator('data256/train/images','data256/train/mask',16)
val = Mygenerator('data256/val/images','data256/val/mask',16)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    patience=10,
    verbose=1,
    min_lr=1e-6,
    min_delta=0.005
)
# model = default_unet()
# model.compile(optimizer=Adam(lr=1e-3),
#                   loss='binary_crossentropy',
#                   metrics=[dice_coef])
# model.compile(optimizer = opt, loss = loss, metrics = [dice_coef])

STEP_SIZE_TRAIN=450//16
STEP_SIZE_VALID=240//16

# STEP_SIZE_TRAIN=tr_img.n//tr_img.batch_size
# STEP_SIZE_VALID=vl_img.n//vl_img.batch_size
history = model.fit_generator(train,steps_per_epoch=STEP_SIZE_TRAIN,validation_data=val,validation_steps=STEP_SIZE_VALID,epochs=100, callbacks=[ reduce_lr])
# Out:
# /var/folders/k8/zqf12b250jz734yvhzlr662h0000gn/T/ipykernel_4925/1087953822.py:36: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train,steps_per_epoch=STEP_SIZE_TRAIN,validation_data=val,validation_steps=STEP_SIZE_VALID,epochs=100, callbacks=[ reduce_lr])
# Epoch 1/100
#  1/28 [>.............................] - ETA: 47:54 - loss: 7.4653 - dice_coef: 0.1475
